# %% [markdown]
# # Lession 17 多模态模型

# %%
import os

from dotenv import load_dotenv
load_dotenv()

from IPython.display import Markdown, display
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model

messages = [
    {
        "role": "user",
        "content": [
            {"type": "image_url", "image_url": {"url": "https://image.tmdb.org/t/p/w500/5XyTQaZcWgn1iqSuxsh5FRzuJjB.jpg"}},
            {"type": "text", "text": "图中描绘的是什么?"},
        ],
    },
]

model = init_chat_model(
    model="qwen-vl-max",
    model_provider="openai",
    base_url=os.getenv("OPENAI_BASE_URL"),
    api_key=os.getenv("OPENAI_API_KEY"),
)

agent = create_agent(model)

res = agent.invoke({"messages": messages})

display(Markdown(res['messages'][-1].content))
# Out:
# 图中描绘的是日本著名漫画《NANA》的封面或宣传图。画面分为上下两部分，分别展示了两位主要角色：
#
# - **上半部分**：一位蓝发、紫色眼睛的女性，表情冷静而略带忧郁，背景是蓝色调，带有星光点缀，象征着她冷静、理性且略带神秘的性格。
# - **下半部分**：一位金发、闭着眼睛的女性，面带温柔的微笑，背景是粉红色调，花瓣飘落，表现出她温柔、感性的一面。
#
# 中间用醒目的红色大字写着“NANA”，下方还有日文“ナナ”（Nana），这是漫画的标题。
#
# 这两位角色分别是：
# - **大原娜娜**（Nana Osaki）：蓝发的摇滚乐队主唱，性格坚强独立。
# - **小松奈奈**（Nana Komatsu）：金发的女孩，憧憬爱情和理想生活，性格温柔敏感。
#
# 她们的名字都叫“Nana”，这也是作品名字的由来。这部作品讲述了她们在东京相遇后，共同经历友情、爱情与成长的故事。
