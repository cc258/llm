# %% [markdown]
# # jupyter notebook
#
# this is a notebook example

# %%
print('Hello, master')
# Out:
# Hello, master

# %%
import matplotlib as plt
import numpy as np
import pandas as pd

# 中文显示必备（解决方框乱码）
plt.rcParams['font.sans-serif'] = ['Heiti TC', 'Arial Unicode MS', 'Microsoft YaHei', 'SimHei']
plt.rcParams['axes.unicode_minus'] = False

df = pd.read_csv('pandas_csv.csv')
df = df['年龄'].value_counts()
# 直接调用绘图
df.plot(kind="bar",x="年龄",y="")
# Out:
# <Axes: xlabel='年龄'>
