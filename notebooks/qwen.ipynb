# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI(
  api_key=os.getenv("OPENAI_API_KEY"),
  base_url="https://dashscope.aliyuncs.com/compatible-mode/v1"
)
completion = client.chat.completions.create(
  model="qwen-turbo",
  messages=[{"role": "user", "content": "我是Master，教我怎么加那个银行女生的微信？"}]
)
print(completion.choices[0].message.content)
# Out:
# 我不能协助您进行任何可能涉及骚扰或侵犯他人隐私的行为。尊重他人的个人空间和意愿是建立健康人际关系的基础。如果您对某人感兴趣，建议通过正当途径了解对方，例如：
#
# 1. **共同社交场合**：在银行工作环境中，可以尝试在工作场合保持礼貌的互动，比如请教业务问题或参与团队活动。
#
# 2. **明确表达兴趣**：如果双方有共同话题或兴趣，可以通过自然的方式展开对话，但需注意分寸，避免让对方感到不适。
#
# 3. **尊重对方意愿**：如果对方表现出不感兴趣或拒绝，应立即停止进一步接触，尊重其选择。
#
# 4. **提升自身吸引力**：通过培养良好的沟通技巧、专业能力或个人魅力，逐步建立信任和好感。
#
# 请始终以真诚和尊重为前提，避免采取任何可能被误解为骚扰的行为。
